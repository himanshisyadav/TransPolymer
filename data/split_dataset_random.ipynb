# %% [markdown]
# ## Notebook for generating multicomponent dataset (for LGBM/others)

# %% [markdown]
# ### Random splitting

# %%
import warnings
warnings.filterwarnings('ignore')
import requests
import os
import json
import csv
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
from rdkit import Chem
import rdkit.Chem.rdMolDescriptors as MolDescriptors
import rdkit.Chem.Descriptors as Descriptors
from sklearn.model_selection import train_test_split

# %%
# %%bash
# pwd
# ls -ltr
# Out:
# /project/rcc/hyadav/TransPolymer/data
# total 355698
# -rw-rw-r-- 1 hyadav rcc-staff     10987 Jun 28 09:51 EPS.csv
# -rw-rw-r-- 1 hyadav rcc-staff     11263 Jun 28 09:51 Eea.csv
# -rw-rw-r-- 1 hyadav rcc-staff     17922 Jun 28 09:51 Egb.csv
# -rw-rw-r-- 1 hyadav rcc-staff    144834 Jun 28 09:51 Egc.csv
# -rw-rw-r-- 1 hyadav rcc-staff     11299 Jun 28 09:51 Ei.csv
# -rw-rw-r-- 1 hyadav rcc-staff     11758 Jun 28 09:52 Nc.csv
# -rw-rw-r-- 1 hyadav rcc-staff    171771 Jun 28 09:52 OPV.csv
# -rw-rw-r-- 1 hyadav rcc-staff    171806 Jun 28 09:52 OPV_aug.csv
# -rw-rw-r-- 1 hyadav rcc-staff   3861748 Jun 28 09:52 PE_I.csv
# -rw-rw-r-- 1 hyadav rcc-staff     25123 Jun 28 09:52 PE_II.csv
# -rw-rw-r-- 1 hyadav rcc-staff     28810 Jun 28 09:52 PE_II_aug.csv
# -rw-rw-r-- 1 hyadav rcc-staff     19747 Jun 28 09:52 Xc.csv
# drwxrwsr-x 2 hyadav rcc-staff      4096 Jun 28 09:52 original datasets
# -rw-rw-r-- 1 hyadav rcc-staff 245980630 Jun 28 09:52 pretrain.csv
# -rw-rw-r-- 1 hyadav rcc-staff  47564048 Jun 28 09:52 pretrain_1M.csv
# -rw-rw-r-- 1 hyadav rcc-staff  23776050 Jun 28 09:52 pretrain_500k.csv
# -rw-rw-r-- 1 hyadav rcc-staff   2379152 Jun 28 09:53 pretrain_50k.csv
# -rw-rw-r-- 1 hyadav rcc-staff    239097 Jun 28 09:53 pretrain_5k.csv
# -rw-rw-r-- 1 hyadav rcc-staff     62903 Jun 28 09:53 test_PE_I.csv
# -rw-rw-r-- 1 hyadav rcc-staff  14581911 Jun 28 09:53 train_PE_I.csv
# -rw-rw-r-- 1 hyadav rcc-staff    693497 Jun 30 11:56 our.csv
# -rw-rw-r-- 1 hyadav rcc-staff    638806 Jul 12 09:34 all_multi_comp_add.csv
# -rw-rw-r-- 1 hyadav rcc-staff    728011 Jul 12 09:34 all_multi_comp.csv
# -rw-rw-r-- 1 hyadav rcc-staff    599883 Jul 12 09:55 our_train.csv
# -rw-rw-r-- 1 hyadav rcc-staff    150336 Jul 12 09:55 our_test.csv
# -rw-rw-r-- 1 hyadav rcc-staff   1577196 Jul 14 11:20 our_combined.csv
# -rw-rw-r-- 1 hyadav rcc-staff   
# -rw-rw-r-- 1 hyadav rcc-staff     69299 Oct 25 12:21 random_test_only_smiles.csv
# -rw-rw-r-- 1 hyadav rcc-staff     69392 Oct 25 12:21 random_val_only_smiles.csv
# -rw-rw-r-- 1 hyadav rcc-staff     75017 Nov  7 10:37 random_val_smiles_temp.csv
# -rw-rw-r-- 1 hyadav rcc-staff    600255 Nov  7 10:37 random_train_smiles_temp.csv
# -rw-rw-r-- 1 hyadav rcc-staff     74970 Nov  7 10:37 random_test_smiles_temp.csv
# -rw-rw-r-- 1 hyadav rcc-staff    129579 Nov  7 13:08 random_val_all_dollar.csv
# -rw-rw-r-- 1 hyadav rcc-staff   1042767 Nov  7 13:08 random_train_all_dollar.csv
# -rw-rw-r-- 1 hyadav rcc-staff    130161 Nov  7 13:08 random_test_all_dollar.csv
# -rw-rw-r-- 1 hyadav rcc-staff    130161 Nov  7 13:55 random_test_all_pipe.csv
# -rw-rw-r-- 1 hyadav rcc-staff   1042767 Nov  7 13:55 random_train_all_pipe.csv
# -rw-rw-r-- 1 hyadav rcc-staff    129579 Nov  7 13:55 random_val_all_pipe.csv
# -rw-rw-r-- 1 hyadav rcc-staff     22852 Nov  8 09:11 ood_all_pipe.csv
# -rw-rw-r-- 1 hyadav rcc-staff   1039798 Nov  8 09:14 freqI_train_all_pipe.csv
# -rw-rw-r-- 1 hyadav rcc-staff     69734 Nov  8 09:14 freqI_test_all_pipe.csv
# -rw-rw-r-- 1 hyadav rcc-staff    114997 Nov  8 09:17 freqII_test_all_pipe.csv
# -rw-rw-r-- 1 hyadav rcc-staff    999723 Nov  8 09:17 freqII_train_all_pipe.csv
# -rw------- 1 hyadav rcc-staff     48149 Nov  9 10:09 split_dataset_random.ipynb

# %%
df_comp = pd.read_csv('all_multi_comp.csv')
y = df_comp['conductivity_log']
rest_df_comp, test_df_comp, y_rest_comp, y_test_comp = train_test_split(df_comp, y, test_size=0.1, random_state=0)
train_df_comp, val_df_comp, y_train_comp, y_val_comp = train_test_split(rest_df_comp, y_rest_comp, test_size=0.11, random_state=0)

# %%
train_df_comp.to_csv('random_train_multi_comp.csv', index=False)
val_df_comp.to_csv('random_val_multi_comp.csv', index=False)
test_df_comp.to_csv('random_test_multi_comp.csv', index=False)

# %%
df = pd.read_csv('all_multi_comp_comb.csv')
df
# Out:
#                    solv_comb_sm  \
# 0           O=C1OCCO1.COC(=O)OC
# 1        O=C1OCCO1.CCCCOC(=O)OC
# 2      O=C1OCCO1.CC(C)COC(=O)OC
# 3      O=C1OCCO1.CCC(C)OC(=O)OC
# 4                   CCOC(=O)OCC
# ...                         ...
# 10191            CS(=O)C.COCCOC
# 10192            CS(=O)C.COCCOC
# 10193            CS(=O)C.COCCOC
# 10194            CS(=O)C.COCCOC
# 10195                   CS(=O)C
#
#                                               salt_sm  conductivity_log
# 0                            [Li+].F[P-](F)(F)(F)(F)F          2.459589
# 1                            [Li+].F[P-](F)(F)(F)(F)F          1.774952
# 2                            [Li+].F[P-](F)(F)(F)(F)F          1.686399
# 3                            [Li+].F[P-](F)(F)(F)(F)F          1.871802
# 4      [Li+].C(F)(F)(F)S(=O)(=O)[N-]S(=O)(=O)C(F)(F)F          0.741937
# ...                                               ...               ...
# 10191                        [Li+].F[P-](F)(F)(F)(F)F          1.547563
# 10192                        [Li+].F[P-](F)(F)(F)(F)F          2.624669
# 10193                        [Li+].F[P-](F)(F)(F)(F)F          2.772589
# 10194                        [Li+].F[P-](F)(F)(F)(F)F          2.687847
# 10195  [Li+].C(F)(F)(F)S(=O)(=O)[N-]S(=O)(=O)C(F)(F)F          0.746688
#
# [10196 rows x 3 columns]

# %%
df_add = pd.read_csv('all_multi_comp_add.csv')
y = df_comp['conductivity_log']
rest_df_add, test_df_add, y_rest_add, y_test_add = train_test_split(df_add, y_add, test_size=0.1, random_state=0)
train_df_add, val_df_add, y_train_add, y_val_add = train_test_split(rest_df_add, y_rest_add, test_size=0.11, random_state=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /software/python-anaconda-2022.05-el8-x86_64/envs/TransPolymer/lib/python3.9/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File /software/python-anaconda-2022.05-el8-x86_64/envs/TransPolymer/lib/python3.9/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /software/python-anaconda-2022.05-el8-x86_64/envs/TransPolymer/lib/python3.9/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'conductivity_log'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /project/rcc/hyadav/TransPolymer/data/split_dataset_random.ipynb Cell 8 line 2
#       <a href='vscode-notebook-cell://ssh-remote%2Bmidway3/project/rcc/hyadav/TransPolymer/data/split_dataset_random.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> df_add = pd.read_csv('all_multi_comp_add.csv')
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bmidway3/project/rcc/hyadav/TransPolymer/data/split_dataset_random.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> y_add = df_add['conductivity_log']
#       <a href='vscode-notebook-cell://ssh-remote%2Bmidway3/project/rcc/hyadav/TransPolymer/data/split_dataset_random.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> rest_df_add, test_df_add, y_rest_add, y_test_add = train_test_split(df_add, y_add, test_size=0.1, random_state=0)
#       <a href='vscode-notebook-cell://ssh-remote%2Bmidway3/project/rcc/hyadav/TransPolymer/data/split_dataset_random.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> train_df_add, val_df_add, y_train_add, y_val_add = train_test_split(rest_df_add, y_rest_add, test_size=0.11, random_state=0)
#
# File /software/python-anaconda-2022.05-el8-x86_64/envs/TransPolymer/lib/python3.9/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File /software/python-anaconda-2022.05-el8-x86_64/envs/TransPolymer/lib/python3.9/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'conductivity_log'

# %%
cols = df.columns
cols
# Out:
# Index(['solv_comb_sm', 'salt_sm', 'conductivity_log'], dtype='object')

# %%
cols_main = ['solvent_1', 'solvent_2', 'solvent_3', 'solvent_4', 'salt_1', 'conductivity_log']
cols_add = ['conc_salt', 'temperature', 'solv_ratio_1', 'solv_ratio_2', 'solv_ratio_3', 'solv_ratio_4']

# %%
y = df['conductivity_log']

# %%
rest_df, test_df, y_rest, y_test = train_test_split(df, y, test_size=0.1, random_state=0)
test_df
# Out:
#                          solv_comb_sm  \
# 6642           CC1COC(=O)O1.O=C1OCCO1
# 3424         CC1COC(=O)O1.CCOC(=O)OCC
# 3779         CC1COC(=O)O1.C1COC(=O)O1
# 7066         CC1COC(=O)O1.CCOC(=O)OCC
# 176                         O=C1OCCO1
# ...                               ...
# 7780  CC1CCCO1.O=C1OCCO1.CC1COC(=O)O1
# 7497           C1COB(OCCOB2OCCCO2)OC1
# 5473         CC1COC(=O)O1.CCOC(=O)OCC
# 8756                  COCCOCCOCCOCCOC
# 1455              CC1COC(=O)O1.COCCOC
#
#                                              salt_sm  conductivity_log
# 6642                        [Li+].F[P-](F)(F)(F)(F)F          2.063161
# 3424        [Li+].[B-]12(OC(=O)C(=O)O1)OC(=O)C(=O)O2          2.004640
# 3779        [Li+].[B-]12(OC(=O)C(=O)O1)OC(=O)C(=O)O2          2.011817
# 7066                            [Li+].[B-](F)(F)(F)F         -1.681759
# 176                        [Li+].F[As-](F)(F)(F)(F)F          2.754934
# ...                                              ...               ...
# 7780                       [Li+].F[As-](F)(F)(F)(F)F          1.266948
# 7497                          [Li+].[O-]Cl(=O)(=O)=O         -8.727914
# 5473             CC[N+](CC)(CC)CC.F[P-](F)(F)(F)(F)F          2.120264
# 8756  [Li+].C(F)(F)(F)S(=O)(=O)[N-]S(=O)(=O)C(F)(F)F          1.079429
# 1455                        [Li+].F[P-](F)(F)(F)(F)F          2.227525
#
# [1020 rows x 3 columns]

# %%
train_df, val_df, y_train, y_val = train_test_split(rest_df, y_rest, test_size=0.11, random_state=0)
train_df
# Out:
#                                            solv_comb_sm  \
# 8357                                CCOCCOCCF.O=C1OCCO1
# 4397                                       CC1COC(=O)O1
# 4649                           CC1COC(=O)O1.CCOC(=O)OCC
# 8266                          COCCOC.COCCOCC(F)(F)C(F)F
# 1124                                       CC1COC(=O)O1
# ...                                                 ...
# 102   FC(F)C(F)(F)COC(F)(F)C(F)F.COC(=O)OCC(F)(F)F.O...
# 1664                               CCCCCCCCCC1COC(=O)O1
# 8946                                    COCCOCCOCCOCCOC
# 2190                           CC1COC(=O)O1.CCOC(=O)OCC
# 9815                            O=S1(=O)CCCC1.COCCOCCOC
#
#                                              salt_sm  conductivity_log
# 8357                        [Li+].F[P-](F)(F)(F)(F)F          1.887070
# 4397                        [Li+].F[P-](F)(F)(F)(F)F          1.077993
# 4649                        [Li+].F[P-](F)(F)(F)(F)F          0.362224
# 8266  [Li+].C(F)(F)(F)S(=O)(=O)[N-]S(=O)(=O)C(F)(F)F          1.857859
# 1124                        [Li+].F[P-](F)(F)(F)(F)F          1.629241
# ...                                              ...               ...
# 102                         [Li+].F[P-](F)(F)(F)(F)F          1.098612
# 1664                   [Li+].C(F)(F)(F)S(=O)(=O)[O-]         -3.028255
# 8946  [Li+].C(F)(F)(F)S(=O)(=O)[N-]S(=O)(=O)C(F)(F)F          1.182280
# 2190                        [Li+].F[P-](F)(F)(F)(F)F          2.515274
# 9815                       [Li+].F[As-](F)(F)(F)(F)F          2.070653
#
# [8166 rows x 3 columns]

# %%
val_df
# Out:
#                             solv_comb_sm  \
# 1992       O=C1OCCO1.CCOC(=O)OC.CC(=O)OC
# 9701                         CS(=O)(=O)F
# 7558  C1COB(OCCOB2OCCCO2)OC1.C1COC(=O)O1
# 7189                           O=C1CCCO1
# 2568            CC1COC(=O)O1.CCOC(=O)OCC
# ...                                  ...
# 1822    C1COC(=O)O1.CCOC(=O)OC.COC(=O)OC
# 2923                        CC1COC(=O)O1
# 6641              CC1COC(=O)O1.O=C1OCCO1
# 6578            CC1COC(=O)O1.CCOC(=O)OCC
# 5694              CC1COC(=O)O1.O=C1OCCO1
#
#                                                 salt_sm  conductivity_log
# 1992                           [Li+].F[P-](F)(F)(F)(F)F          2.541602
# 9701     [Li+].C(F)(F)(F)S(=O)(=O)[N-]S(=O)(=O)C(F)(F)F          0.576613
# 7558                             [Li+].[O-]Cl(=O)(=O)=O          2.271271
# 7189  [B-](C1=CC=CC=C1)(C2=CC=CC=C2)(C3=CC=CC=C3)C4=...         -1.525329
# 2568                           [Li+].F[P-](F)(F)(F)(F)F          1.332102
# ...                                                 ...               ...
# 1822           [Li+].[B-]12(OC(=O)C(=O)O1)OC(=O)C(=O)O2          0.683489
# 2923           [Li+].[B-]12(OC(=O)C(=O)O1)OC(=O)C(=O)O2          1.087214
# 6641                           [Li+].F[P-](F)(F)(F)(F)F          2.389038
# 6578                    [B-](F)(F)(F)F.CC[N+](CC)(CC)CC          1.590862
# 5694                CC[N+](CC)(CC)CC.F[P-](F)(F)(F)(F)F          1.920650
#
# [1010 rows x 3 columns]

# %%
val_df.to_csv('val_multi_comp_2d.csv', index=False)

# %%
test_df.to_csv('test_multi_comp_2d.csv', index=False)

# %%
train_df.to_csv('train_multi_comp_2d.csv', index=False)
